# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd
df=pd.read_excel("HRM Project list.xlsx")
print(df)
df.rename(columns={'Date Start':'date_start','Date End date':'date_end'},inplace=True)
df['date_start']=pd.to_datetime(df.date_start)
df['date_end']=pd.to_datetime(df.date_end)
df.replace({pd.NaT: ''}, inplace=True)

print(df)
from webdriver_manager.chrome import ChromeDriverManager
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from time import sleep
import pyautogui as pg
import time
from selenium.webdriver.support.ui import Select
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get("https://hrm.codepth.com/")
s="COD0005"#user id
password="5ec6131039dba"#Passsword
time.sleep(5)
driver.maximize_window()
driver.find_element_by_xpath('/html/body/div[4]/div/div/form/div[2]/div[1]/input').send_keys(s)
driver.find_element_by_xpath('/html/body/div[4]/div/div/form/div[2]/div[2]/input').send_keys(password)
driver.find_element_by_xpath('/html/body/div[4]/div/div/form/div[2]/div[3]/input').click()
time.sleep(5)
#/html/body/div/div/div[1]/div[2]/div[2]/div/ul/li[1]
"""
#Code sfollow the conventional approach the step by step one not needed if go to the project tab directly
try:
    driver.find_element_by_class_name("flexMenu-viewMore active").click()#More tab click
    driver.find_element_by_id("main_parent_130").click()#Time tab click
except:
    driver.find_element_by_id("main_parent_130").click()#Time tab click
#driver.find_element_by_xpath('/html/body/div[1]/div/div/div[2]/div[2]/div/ul/li[10]/ul/li[1]').click()
#/html/bodiv/div/div[1]/div[2]/div[2]/div/ul/li[10]
driver.find_element_by_id("projectsli").click()#Time tarb click
#class="flexMenu-viewMore active"
time.sleep(3)
#Walk through Needs to be changd ADD button is not working
"""
try:
    driver.find_element_by_class_name("sprite addrecord").click()
except:
    driver.get("https://hrm.codepth.com/index.php/timemanagement/projects/edit")
#sprite addrecord
#class="reports-div active"
for i in range(0,len(df)):
    
    driver.find_element_by_id("project_name").send_keys(df["Project"][i])   #SELECTING PROJECT NAME
    
    #PROJECT STATUS
    STATUS=df["Status"][i]
    stat = Select(driver.find_element_by_id('project_status'))
    for option in stat.options:
        option_text = option.text
        if STATUS in option_text:
            option.click()
            break
    
    #BASE_PROJECT
    base_proj=df["Base Project if Any"][i]
    bp = Select(driver.find_element_by_id('base_project'))
    for option in bp.options:
        option_text = option.text
        if base_proj in option_text:
            option.click()
            break
            
    
    #SELECTING CLIENT
    client=df["Client"][i]
    cli = Select(driver.find_element_by_id('client_id'))
    for option in cli.options:
        option_text = option.text
        if client in option_text:
            option.click()
            break
    
    #SELECTING CURRENCY
    curr=df["Currency"][i]
    currency = Select(driver.find_element_by_id('currency_id'))
    for option in currency.options:
        option_text = option.text
        if curr in option_text:
            option.click()
            break
    
    
    
    protype=df["Project type"][i]               #SELECTING PROJECT TYPE
    print(protype)
    if(str(protype)=='Non Billable '):
        driver.find_element_by_id("project_type-non_billable").click()
    if(str(protype)=='Billable'):
        driver.find_element_by_id("project_type-billable").click()
    if(str(protype)=='Revenue generation'):
        driver.find_element_by_id("project_type-revenue").click()

        
    
    
    if(df["date_start"][i]==''):
        pass
    else:
        #print(df["date_start"][i])
        start_year=str(df["date_start"][i])[:4]
        start_date=str(df["date_start"][i])[8:10]
        start_month=str(df["date_start"][i].month_name())[:3]
        print(start_year)
        print(start_month)
        print(start_date)
        
        driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[2]/form/div[2]/div[7]/div/div[1]/div/img").click()
        time.sleep(1)
        sm1=Select(driver.find_element_by_class_name('ui-datepicker-month'))
        for option in sm1.options:
            option_text = option.text
            if start_month in option_text:
                option.click()
                break
        sm2=Select(driver.find_element_by_class_name('ui-datepicker-year'))
        for option in sm2.options:
            option_text = option.text
            if start_year in option_text:
                option.click()
                break
        
        new_xpath="//table/tbody/tr/td/a[text()='"+str(start_date)+"']"
        datepath=driver.find_element_by_xpath(new_xpath)
        datepath.click()
        
        
    if(df["date_end"][i]==''):
        
        pass
    else:
        #print(df["date_start"][i])
        end_year=str(df["date_end"][i])[:4]
        end_date=str(df["date_end"][i])[8:10]
        end_month=str(df["date_end"][i].month_name())[:3]
        print(end_year)
        print(end_month)
        print(end_date)
        
        driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[2]/form/div[2]/div[7]/div/div[2]/div/img").click()
        time.sleep(1)
        sm1=Select(driver.find_element_by_class_name('ui-datepicker-month'))
        for option in sm1.options:
            option_text = option.text
            if end_month in option_text:
                option.click()
                break
        sm2=Select(driver.find_element_by_class_name('ui-datepicker-year'))
        for option in sm2.options:
            option_text = option.text
            if end_year in option_text:
                option.click()
                break
        new_xpath="//table/tbody/tr/td/a[text()='"+str(end_date)+"']"
        datepath=driver.find_element_by_xpath(new_xpath)
        datepath.click()
    
    
    driver.find_element_by_id("estimated_hrs").send_keys(str(df["Hours"][i]))     #SELECTNG HRS
    driver.find_element_by_id("description").send_keys(df["Description"][i])      #ENTERING DESCRIPTION
    
    driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[2]/form/div[2]/div[9]/input").click()
    sleep(2)
    
    
    
     #tasks page
    
    
    
    
    
    
    
    task=(df["Task"][i])
    driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[3]/span").click()
    sleep(2)
    driver.find_element_by_id("idradtasktype_new").click()
    sleep(2)
    driver.find_element_by_id("idtxttask").click()
    sleep(2)
    driver.find_element_by_id("idtxttask").send_keys(task)
    sleep(2)
    driver.find_element_by_xpath("/html/body/div[4]/div[2]/div[2]/div/div[2]/label/input").click()
    sleep(2)
    driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/button[1]/span").click()
    sleep(2)

    try:
        driver.find_element_by_xpath("//span[contains(text(), 'This task already exists.')]")
        print('yes')
        driver.find_element_by_id("idradtasktype_default").click()
        sleep(2)
        rows=len(driver.find_elements_by_xpath("/html/body/div[4]/div[2]/div[2]/div/div[2]/div[2]/div/div[1]/table/tbody/tr"))
        cols=len(driver.find_elements_by_xpath("/html/body/div[4]/div[2]/div[2]/div/div[2]/div[2]/div/div[1]/table/tbody/tr[1]/td"))

        print(rows,cols)

        for r in range(1,rows+1):
    
            hi=driver.find_element_by_xpath("/html/body/div[4]/div[2]/div[2]/div/div[2]/div[2]/div/div[1]/table/tbody/tr["+str(r)+"]/td[2]").text
            if(hi==task):
                driver.find_element_by_xpath("/html/body/div[4]/div[2]/div[2]/div/div[2]/div[2]/div/div[1]/table/tbody/tr["+str(r)+"]/td[1]/input").click()
                driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/button[1]/span").click()
                sleep(2)
                break
        

    except:
        print('newtask')
    
    
    
    
    
    
    
    
    
    #RESOURCES
    
    driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[1]/ul/li[3]/div[2]/span").click()
    sleep(2)
    driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[4]/form/div/div/div[3]/div[1]/div/div[1]/table/thead[1]/tr[1]/td/span").click()
    sleep(2)
    driver.find_element_by_id("idradresourcetype_emp").click()
    sleep(2)
    a=df["Employee"][i]
    l1=list(a.split(','))              #employee ids
    for i in l1:
        path="//div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='"+str(i)+"']"
        WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, path))).click()
        sleep(2)
    driver.find_element_by_xpath("/html/body/div[4]/div[3]/div/button[1]/span").click()
    sleep(2)
    l2=[]
    l2.extend(l1)
    l2.append(s)
    print(l2)
    driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[1]/ul/li[2]").click()
    sleep(3)
    geta=driver.find_element_by_class_name('sprite asi_resor')
    geta.click()
    sleep(2)
    #for i in l2:
     #   path="//div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='"+str(i)+"']"
      #  WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, path))).click()
       # sleep(2)
# Out:
# [WDM] - Cache is valid for [07/06/2020]
# [WDM] - Looking for [chromedriver 83.0.4103.39 win32] driver in cache
# [WDM] - Driver found in cache [C:\Users\KIIT\.wdm\drivers\chromedriver\83.0.4103.39\win32\chromedriver.exe]
#   Project     Status Base Project if Any   Client      Currency  \
# 0     ABC  Initiated                 Abc  CODEPTH  Indian Rupee
#
#     Project type  Date Start  Date End date  Hours  \
# 0  Non Billable          NaN            NaN     30
#
#                       Description                 Employee                Task
# 0  For bulding a Analytics Engine  COD0012,COD0015,COD0060  Fill the timesheet
#   Project     Status Base Project if Any   Client      Currency  \
# 0     ABC  Initiated                 Abc  CODEPTH  Indian Rupee
#
#     Project type date_start date_end  Hours                     Description  \
# 0  Non Billable                          30  For bulding a Analytics Engine
#
#                   Employee                Task
# 0  COD0012,COD0015,COD0060  Fill the timesheet
#
# Non Billable
# yes
# 2 2
# ['COD0012', 'COD0015', 'COD0060', 'COD0005']
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-10-d3510c471a17> in <module>
#     249     driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[1]/ul/li[2]").click()
#     250     sleep(3)
# --> 251     geta=driver.find_element_by_class_name('sprite asi_resor')
#     252     geta.click()
#     253     sleep(2)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_class_name(self, name)
#     562             element = driver.find_element_by_class_name('foo')
#     563         """
# --> 564         return self.find_element(by=By.CLASS_NAME, value=name)
#     565
#     566     def find_elements_by_class_name(self, name):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".sprite asi_resor"}
#   (Session info: chrome=83.0.4103.97)

# %%
/html/body/div[4]/div[2]/div[2]/div/div[2]/div[2]/div/div[1]/table/tbody/tr[6]/td[1]/input

# %%
driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[2]/div[2]/div/div[2]/div/div[1]/div[4]/div[5]/div/div[4]/form/div/div/div[3]/div[1]/div/div[1]/table/thead[1]/tr[1]/td/span").click()

# %%
driver.find_element_by_id("idradresourcetype_emp").click()

# %%
array=['Ekansh Mah','Aritrik Guha','Niladri Bit']

# %%
l1=['COD0012','COD0015','COD0060']

# %%
for i in l1:
    print(i)
# Out:
# COD0012
# COD0015
# COD0060

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='COD0012']"))).click()

# %%
for i in l1:
    print(i)
    path="//div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='"+str(i)+"']"
    print(path)
    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, path))).click()
    sleep(2)
# Out:
# COD0012
# //div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='COD0012']
# COD0015
# //div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='COD0015']
# COD0060
# //div[@id='idresourcecontent']//span[@class='empuid member_id' and text()='COD0060']

# %%
for i in array:
    print(i)
    path="//div[@id='idresourcecontent']//span[@class='empname member_name' and text()='"+str(i)+"']"
    print(path)
# Out:
# Ekansh Mah
# //div[@id='idresourcecontent']//span[@class='empname member_name' and text()='Ekansh Mah']
# Aritrik Guha
# //div[@id='idresourcecontent']//span[@class='empname member_name' and text()='Aritrik Guha']
# Niladri Bit
# //div[@id='idresourcecontent']//span[@class='empname member_name' and text()='Niladri Bit']
